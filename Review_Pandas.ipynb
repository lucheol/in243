# %%
import pandas as pd

# %%
# https://goo.gl/1oz6Xf
movies_df = pd.read_csv('movie_metadata.csv')

# %%
movies_df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
# Filmes são avaliados de forma melhor se forem coloridos?
mean_by_color = movies_df.groupby('color')['imdb_score'].mean().reset_index()
count_by_color = movies_df.groupby('color')['imdb_score'].count().reset_index()

# %%
mean_by_color
# Out:
#               color  imdb_score
# 0   Black and White    7.227273
# 1             Color    6.409533

# %%
count_by_color
# Out:
#               color  imdb_score
# 0   Black and White         209
# 1             Color        4815

# %%
movies_df.groupby('director_name')['color'].count()
# Out:
# director_name
# A. Raven Cruz                  1
# Aaron Hann                     1
# Aaron Schneider                1
# Aaron Seltzer                  1
# Abel Ferrara                   1
# Adam Brooks                    1
# Adam Carolla                   1
# Adam Goldberg                  1
# Adam Green                     1
# Adam Jay Epstein               1
# Adam Marcus                    1
# Adam McKay                     6
# Adam Rapp                      1
# Adam Rifkin                    2
# Adam Shankman                  8
# Adrian Lyne                    4
# Adrienne Shelly                1
# Agnieszka Holland              1
# Agnieszka Wojtowicz-Vosloo     1
# Agustín Díaz Yanes             1
# Aki Kaurismäki                 1
# Akira Kurosawa                 2
# Akiva Goldsman                 1
# Akiva Schaffer                 3
# Al Franklin                    1
# Al Silliman Jr.                1
# Alain Resnais                  1
# Alan Alda                      1
# ...

# %%
movies_df[movies_df['imdb_score'] > 9]['movie_title']
# Out:
# 1937        The Shawshank Redemption
# 2765    Towering Inferno
# 2824             Dekalog
# 3207             Dekalog
# 3466                   The Godfather
# 4409            Kickboxer: Vengeance
# Name: movie_title, dtype: object

# %%
movies_df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df_r = pd.read_csv('rouanet.csv')

# %%
df_r.groupby(['proponente'])['valor_aprovado'].sum().reset_index().sort_values(['valor_aprovado'])
# Out:
#                                            proponente  valor_aprovado
# 97                                  WILLIAM HEGENBERG        38192.00
# 32          CENTRO DE TRADICOES GAUCHAS RONDA CRIOULA        49515.40
# 42                     FRANCISCO FELIPE DE PAULA NETO        50155.82
# 2                         Sociedade Porvir Científico        54714.88
# 18                    ASSOCIAÇÃO PAULISTA DE MEDICINA       100529.00
# 11                                ANDRE YUKI YOSHIKAI       105963.00
# 21                        Aristeu Oliveira dos Santos       110484.00
# 45                            Gabriel Rodrigues Silva       113836.80
# 6                      ADERE PRODUCOES ARTISTICA LTDA       114972.00
# 98                          Wagner Raimundo Gonçalves       117912.00
# 76                              NATALIA TAVARES SOUZA       118475.50
# 48                     INSPETORIA SALESIANA SAO PIO X       160382.38
# ...

# %%
voos = pd.read_csv('voos.csv', delimiter=';')

# %%
voos.head()
# Out:
#   sg_empresa_icao nr_voo  cd_di cd_tipo_linha sg_icao_origem sg_icao_destino  \
# 0             TAM   3795    0.0             N           SBSV            SBSP
# 1             AZU   5170    0.0             N           SBPA            SBFI
# 2             AEA     83    0.0             I           LEMD            SBSV
# 3             TAM   3744    0.0             N           SBSP            SBRP
# 4             AZU   5700    0.0             N           SBRF            SBSG
#
#   dt_partida_prevista   dt_partida_real dt_chegada_prevista   dt_chegada_real  \
# 0    21/12/2019 14:25  21/12/2019 14:26    21/12/2019 17:00  21/12/2019 16:50
# 1    22/12/2019 12:45  22/12/2019 12:38    22/12/2019 14:05  22/12/2019 14:00
# 2    24/12/2019 11:25  24/12/2019 12:01    24/12/2019 20:55  24/12/2019 20:59
# 3    18/12/2019 15:15  18/12/2019 15:12    18/12/2019 16:20  18/12/2019 16:09
# 4    17/12/2019 23:20  17/12/2019 23:20    18/12/2019 00:25  18/12/2019 00:25
#
#     situacao cd_justificativa
# ...

# %%
voos[voos['sg_empresa_icao'] == 'AVA'].groupby(['situacao', 'sg_empresa_icao']).count()
# Out:
#                            nr_voo  cd_di  cd_tipo_linha  sg_icao_origem  \
# situacao  sg_empresa_icao
# REALIZADO AVA                 217    217            217             217
#
#                            sg_icao_destino  dt_partida_prevista  \
# situacao  sg_empresa_icao
# REALIZADO AVA                          217                  217
#
#                            dt_partida_real  dt_chegada_prevista  \
# situacao  sg_empresa_icao
# REALIZADO AVA                          217                  217
#
#                            dt_chegada_real  cd_justificativa
# situacao  sg_empresa_icao
# REALIZADO AVA                          217               130
